# %%
import pandas as pd
from sklearn import linear_model

# %%
df=pd.read_csv("C:\\Users\\Dell\\Documents\\vaishaliml\\job_dataset.csv")

# %%
#we'll find out the premium whose age is 25 experience is 1 years and income is 20000 whose age is 50,experience is 6 years and income is 65000.

# %%
df
# Out:
#     age  experience  income  premium
# 0    25         1.0   30450    18000
# 1    30         3.0   35670    27000
# 2    47         2.0   31580    38000
# 3    32         5.0   40130    38000
# 4    43        10.0   47830    39000
# 5    51         7.0   41630    40000
# 6    28         5.0   41340    56000
# 7    33         4.0   37650    65000
# 8    37         5.0   40250    65000
# 9    39         8.0   45150    70000
# 10   29         1.0   27840    72000
# 11   47         9.0   46110    75000
# 12   54         5.0   36720    79000
# 13   51         4.0   34800    81000
# 14   44         NaN   51300    84000
# 15   41         6.0   38900    84000
# 16   58        17.0   63600    90000
# 17   23         1.0   30870    90000
# 18   44         9.0   44190    96000

# %%
df.experience.mean()
# Out:
# 5.666666666666667

# %%
df.experience
# Out:
# 0      1.0
# 1      3.0
# 2      2.0
# 3      5.0
# 4     10.0
# 5      7.0
# 6      5.0
# 7      4.0
# 8      5.0
# 9      8.0
# 10     1.0
# 11     9.0
# 12     5.0
# 13     4.0
# 14     NaN
# 15     6.0
# 16    17.0
# 17     1.0
# 18     9.0
# Name: experience, dtype: float64

# %%
mean_experience=df.experience.mean()

# %%
df.experience = df.experience.fillna(mean_experience)

# %%
df
# Out:
#     age  experience  income  premium
# 0    25    1.000000   30450    18000
# 1    30    3.000000   35670    27000
# 2    47    2.000000   31580    38000
# 3    32    5.000000   40130    38000
# 4    43   10.000000   47830    39000
# 5    51    7.000000   41630    40000
# 6    28    5.000000   41340    56000
# 7    33    4.000000   37650    65000
# 8    37    5.000000   40250    65000
# 9    39    8.000000   45150    70000
# 10   29    1.000000   27840    72000
# 11   47    9.000000   46110    75000
# 12   54    5.000000   36720    79000
# 13   51    4.000000   34800    81000
# 14   44    5.666667   51300    84000
# 15   41    6.000000   38900    84000
# 16   58   17.000000   63600    90000
# 17   23    1.000000   30870    90000
# 18   44    9.000000   44190    96000

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['age','experience','income']],df['premium'])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([4.93741657e+02, 4.11901453e+02, 3.79202341e-01])

# %%
reg.intercept_
# Out:
# 26258.44553933439

# %%
reg.predict([[25,1,20000]])
# Out:
# C:\Users\Dell\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([46597.93524831])

# %%
reg.predict([[50,6,65000]])
# Out:
# C:\Users\Dell\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([78065.08930531])

# %%
4.93741657e+02*25+4.93741657e+02*1+3.79202341e-01*20000+26258.44553933439
# Out:
# 46679.77544133439

# %%
4.93741657e+02*50+4.11901453e+02*6+3.79202341e-01*65000+26258.44553933439
# Out:
# 78065.08927233439
